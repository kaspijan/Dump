# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#6.):
x = 0.7
N = [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 16]
res = [
0.642833333333333,
0.644233916666667,
0.644217576527778,
0.644217687731501,
0.644217687236139,
0.644217687237695,
0.644217687237691,
0.644217687237691,
0.644217687237691,
0.644217687237691,
0.644217687237691,
0.644217687237691]

exact = np.sin(x)
res = np.array(res)

plt.scatter(N, np.abs(res - exact)/exact)
#plt.xlim(1.5, 16)
#plt.ylim(-0.02, 0.04)
plt.axhline(y = 0, ls ='--', color = 'black')
plt.xlabel('N')
plt.ylabel('relative error')
plt.title('x = 0.7')
# Out:
# Text(0.5, 1.0, 'x = 0.7')

# %%
x = 1.5
N = [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 16]
res = [
0.937500000000000,
1.000781250000000,
0.997391183035714,
0.997497122628348,
0.997494955682135,
0.997494986936167,
0.997494986601303,
0.997494986604073,
0.997494986604054,
0.997494986604055,
0.997494986604055,
0.997494986604055]

exact = np.sin(x)
res = np.array(res)

plt.scatter(N, np.abs(res - exact)/exact)
#plt.xlim(1.5, 16)
#plt.ylim(-0.02, 0.04)
plt.axhline(y = 0, ls ='--', color = 'black')
plt.xlabel('N')
plt.ylabel('relative error')
plt.title('x = 1.5')
# Out:
# Text(0.5, 1.0, 'x = 1.5')

# %%
x = 5
N = [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 16]
res = [
-15.833333333333336,
10.208333333333336,
-5.292658730158731,
0.089630180776014,
-1.133617298981883,
-0.937584049020681,
-0.960921340682729,
-0.958776369022614,
-0.958933165196599,
-0.958924293212823,
-0.958924274683652,
-0.958924274663152]

exact = np.sin(x)
res = np.array(res)

plt.scatter(N, np.abs(res - exact)/exact)
#plt.xlim(1.5, 16)
#plt.ylim(-0.02, 0.04)
plt.axhline(y = 0, ls ='--', color = 'black')
plt.xlabel('N')
plt.ylabel('relative error')
plt.title('x = 5')
# Out:
# Text(0.5, 1.0, 'x = 5')

# %%
x = 10
N = [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 16, 20, 25, 30]
res = [
-156.666666666666690,
676.666666666666740,
-1307.460317460317800,
1448.271604938271800,
-1056.939233605900700,
548.965150076261350,
-215.751223105720560,
65.394502328831663,
-16.811850137411682,
-1.107079244651095,
-0.554221114850603,
-0.544127277005709,
-0.544021113721139,
-0.544021110889360,
-0.544021110889361]


res2 = [-0.554221114850603,
-0.544127277005709,
-0.544021113721139,
-0.544021110889360,
-0.544021110889361]
N2=[14, 16, 20, 25, 30]

exact = np.sin(x)
res = np.array(res)

plt.scatter(N, np.abs(res - exact)/exact)
#plt.xlim(1.5, 16)
#plt.ylim(-0.02, 0.04)
plt.axhline(y = 0, ls ='--', color = 'black')
plt.xlabel('N')
plt.ylabel('relative error')
plt.title('x = 10')
print(exact)
# Out:
# -0.5440211108893698

# %%
res2 = np.array(res2)

plt.scatter(N2, np.abs(res2 - exact)/exact)
#plt.xlim(1.5, 16)
#plt.ylim(-0.02, 0.04)
plt.axhline(y = 0, ls ='--', color = 'black')
plt.xlabel('N')
plt.ylabel('relative error')
plt.title('x = 10')
print(exact)
# Out:
# -0.5440211108893698
