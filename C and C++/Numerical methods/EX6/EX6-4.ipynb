# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 2.3
m = 1.3

w = (k/m)**0.5
T = 2*np.pi/w

E0 = 0.5*k
N = 100

# %%
print('N =', N)
# Out:
# N = 100

# %%
#t = np.linspace(0, 6*T, len(x))
dt = 6*T/N
t = np.arange(0, 6*T, dt)

x_anal = [np.cos(w*tt) for tt in t]
v_anal = [-w*np.sin(w*tt) for tt in t]
e_anal = [1 for tt in t]

# %%
x = [1.000000, 0.929780, 0.729023, 0.425918, 0.063026, -0.308700, -0.637070, -0.875983, -0.991899, -0.968547\
, -0.809213, -0.536271, -0.188047, 0.186564, 0.534968, 0.808248, 0.968040, 0.991912, 0.876520\
, 0.638068, 0.310042, -0.061502, -0.424396, -0.727691, -0.928806, -0.999509, -0.929879, -0.729696\
, -0.427071, -0.064498, 0.307117, 0.635597, 0.874828, 0.991223, 0.968446, 0.809700, 0.537278\
, 0.189434, -0.184994, -0.533433, -0.806965, -0.967189, -0.991613, -0.876814, -0.638914, -0.311321\
, 0.059969, 0.422825, 0.726302, 0.927795, 0.999017, 0.929974, 0.730366, 0.428223, 0.065968\
, -0.305534, -0.634124, -0.873671, -0.990545, -0.968342, -0.810185, -0.538284, -0.190819, 0.183424\
, 0.531899, 0.805682, 0.966337, 0.991311, 0.877105, 0.639758, 0.312598, -0.058438, -0.421255\
, -0.724913, -0.926782, -0.998522, -0.930068, -0.731034, -0.429372, -0.067437, 0.303952, 0.632651\
, 0.872513, 0.989865, 0.968236, 0.810667, 0.539287, 0.192201, -0.181856, -0.530365, -0.804398\
, -0.965483, -0.991007, -0.877394, -0.640598, -0.313873, 0.056908, 0.419685, 0.723523, 0.925767\
]


v = [0.000000, -0.489567, -0.910380, -1.203359, -1.327376, -1.265023, -1.025064, -0.641196, -0.167319, 0.330031\
, 0.781026, 1.122347, 1.306077, 1.306426, 1.123354, 0.782570, 0.331927, -0.165302, -0.639302\
, -1.023526, -1.264032, -1.327058, -1.203764, -0.911465, -0.491209, -0.002003, 0.487465, 0.908473\
, 1.201916, 1.326598, 1.265021, 1.025838, 0.642636, 0.169224, -0.327930, -0.779022, -1.120722\
, -1.305059, -1.306159, -1.123875, -0.783805, -0.333703, 0.163234, 0.637233, 1.021746, 1.262791\
, 1.326531, 1.204023, 0.912476, 0.492828, 0.004004, -0.485363, -0.906566, -1.200471, -1.325818\
, -1.265016, -1.026608, -0.644073, -0.171126, 0.325829, 0.777018, 1.119096, 1.304040, 1.305889\
, 1.124392, 0.785037, 0.335476, -0.161167, -0.635164, -1.019965, -1.261548, -1.326000, -1.204280\
, -0.913483, -0.494445, -0.006003, 0.483262, 0.904658, 1.199024, 1.325036, 1.265007, 1.027374\
, 0.645507, 0.173026, -0.323729, -0.775014, -1.117469, -1.303018, -1.305616, -1.124906, -0.786266\
, -0.337247, 0.159103, 0.633095, 1.018183, 1.260303, 1.325467, 1.204533, 0.914487, 0.496059\
]


E = [1.150000 ,1.149955 ,1.149910 ,1.149865 ,1.149820 ,1.149775 ,1.149730 ,1.149685 ,1.149640 ,1.149595\
 ,1.149550 ,1.149505 ,1.149460 ,1.149415 ,1.149370 ,1.149325 ,1.149280 ,1.149235 ,1.149190\
 ,1.149145 ,1.149100 ,1.149055 ,1.149010 ,1.148965 ,1.148920 ,1.148875 ,1.148830 ,1.148785\
 ,1.148740 ,1.148695 ,1.148650 ,1.148605 ,1.148560 ,1.148515 ,1.148470 ,1.148425 ,1.148380\
 ,1.148335 ,1.148290 ,1.148245 ,1.148200 ,1.148155 ,1.148110 ,1.148065 ,1.148020 ,1.147975\
 ,1.147930 ,1.147885 ,1.147840 ,1.147795 ,1.147750 ,1.147705 ,1.147660 ,1.147615 ,1.147571\
 ,1.147526 ,1.147481 ,1.147436 ,1.147391 ,1.147346 ,1.147301 ,1.147256 ,1.147211 ,1.147166\
 ,1.147121 ,1.147076 ,1.147031 ,1.146986 ,1.146942 ,1.146897 ,1.146852 ,1.146807 ,1.146762\
 ,1.146717 ,1.146672 ,1.146627 ,1.146582 ,1.146537 ,1.146492 ,1.146448 ,1.146403 ,1.146358\
 ,1.146313 ,1.146268 ,1.146223 ,1.146178 ,1.146133 ,1.146088 ,1.146044 ,1.145999 ,1.145954\
 ,1.145909 ,1.145864 ,1.145819 ,1.145774 ,1.145729 ,1.145685 ,1.145640 ,1.145595 ,1.145550\
]

# %%
plt.plot(t, x, label='Euler')
plt.plot(t, x_anal, label='analytical', ls = '--')
plt.legend()
plt.title('Position x')
plt.xlabel('t')
plt.ylabel('x')
# Out:
# Text(0, 0.5, 'x')

# %%
plt.plot(t, v, label='Euler')
plt.plot(t, v_anal, label='analytical', ls = '--')
plt.legend()
plt.title('Velocity v')
plt.xlabel('t')
plt.ylabel('v')
# Out:
# Text(0, 0.5, 'v')

# %%
plt.plot(t, np.array(E)/E0, label='Euler')
plt.plot(t, e_anal, label='analytical', ls = '--')
plt.legend()
plt.title('Energy')
plt.xlabel('t')
plt.ylabel('E/E0')
# Out:
# Text(0, 0.5, 'E/E0')
